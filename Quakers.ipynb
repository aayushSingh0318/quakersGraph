# %%
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt
import networkx as nx
import nx_altair as nxa

# %%
nodelist_df = pd.read_csv ('quakers_nodelist.csv')
edgelist_df = pd.read_csv ('quakers_edgelist.csv')

# %%
import csv

import networkx as nx

# read nodelist

with open ('quakers_nodelist.csv', 'r') as nodecsv:

    nodereader = csv.reader (nodecsv)

    nodes = [n for n in nodereader][1:]

# get the list of node names

node_names = [n[0] for n in nodes]

# read in the edgelist

with open ('quakers_edgelist.csv', 'r') as edgecsv:

    edgereader = csv.reader (edgecsv)

    edges = [tuple(e) for e in edgereader][1:]

# create the graph

G = nx.Graph()

G.add_nodes_from (node_names)

G.add_edges_from (edges)

# %%
nxa.draw_networkx(G).properties(width=1000, height=1000)
# Out:
# alt.LayerChart(...)

# %%
print('No of characters: ', len(G.nodes))
print('No of connections: ', len(G.edges))
# Out:
# No of characters:  119
# No of connections:  174

# %%
for name in nodelist_df['Name']:
    G.add_node(name)

historical_significance = dict(nodelist_df[['Name', 'Historical Significance']].values)
gender = dict(nodelist_df[['Name', 'Gender']].values)
birthdate = dict(nodelist_df[['Name', 'Birthdate']].values)
deathdate = dict(nodelist_df[['Name', 'Deathdate']].values)
node_id = dict(nodelist_df[['Name', 'ID']].values)

nx.set_node_attributes(G, historical_significance, 'Historical Significance')
nx.set_node_attributes(G, gender, 'Gender')
nx.set_node_attributes(G, birthdate, 'Birthdate')
nx.set_node_attributes(G, deathdate, 'Deathdate')
nx.set_node_attributes(G, node_id, 'ID')

for source, target in edgelist_df.values:
    G.add_edge(source, target)

# %%
for node in G.nodes(data=True):
    print(node)
# Out:
# ('Joseph Wyeth', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1663, 'Deathdate': 1731, 'ID': 10013191})
# ('Alexander Skene of Newtyle', {'Historical Significance': 'local politician and author', 'Gender': 'male', 'Birthdate': 1621, 'Deathdate': 1694, 'ID': 10011149})
# ('James Logan', {'Historical Significance': 'colonial official and scholar', 'Gender': 'male', 'Birthdate': 1674, 'Deathdate': 1751, 'ID': 10007567})
# ('Dorcas Erbery', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1656, 'Deathdate': 1659, 'ID': 10003983})
# ('Lilias Skene', {'Historical Significance': 'Quaker preacher and poet', 'Gender': 'male', 'Birthdate': 1626, 'Deathdate': 1697, 'ID': 10011152})
# ('William Mucklow', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1713, 'ID': 10008595})
# ('Thomas Salthouse', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1691, 'ID': 10010643})
# ('William Dewsbury', {'Historical Significance': 'Quaker activist', 'Gender': 'male', 'Birthdate': 1621, 'Deathdate': 1688, 'ID': 10003478})
# ('John Audland', {'Historical Significance': 'Quaker preacher', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1664, 'ID': 10000411})
# ('Richard Claridge', {'Historical Significance': 'Quaker minister and schoolmaster', 'Gender': 'male', 'Birthdate': 1649, 'Deathdate': 1723, 'ID': 10002469})
# ('William Bradford', {'Historical Significance': 'printer', 'Gender': 'male', 'Birthdate': 1663, 'Deathdate': 1752, 'ID': 10001445})
# ('Fettiplace Bellers', {'Historical Significance': 'philosophical writer and playwright', 'Gender': 'male', 'Birthdate': 1687, 'Deathdate': 1750, 'ID': 10000933})
# ('John Bellers', {'Historical Significance': 'political economist and cloth merchant', 'Gender': 'male', 'Birthdate': 1654, 'Deathdate': 1725, 'ID': 10000934})
# ('Isabel Yeamans', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1637, 'Deathdate': 1704, 'ID': 10013226})
# ('George Fox the younger', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1551, 'Deathdate': 1661, 'ID': 10004523})
# ('George Fox', {'Historical Significance': ' a founder of the Religious Society of Friends (Quakers)', 'Gender': 'male', 'Birthdate': 1624, 'Deathdate': 1691, 'ID': 10004524})
# ('John Stubbs', {'Historical Significance': 'Quaker minister', 'Gender': 'male', 'Birthdate': 1618, 'Deathdate': 1675, 'ID': 10011695})
# ('Anne Camm', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1627, 'Deathdate': 1705, 'ID': 10001967})
# ('John Camm', {'Historical Significance': 'Quaker preacher', 'Gender': 'male', 'Birthdate': 1605, 'Deathdate': 1657, 'ID': 10001968})
# ('Thomas Camm', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1640, 'Deathdate': 1708, 'ID': 10001969})
# ('Katharine Evans', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1618, 'Deathdate': 1692, 'ID': 10004036})
# ('Lydia Lancaster', {'Historical Significance': 'Quaker minister', 'Gender': 'female', 'Birthdate': 1683, 'Deathdate': 1761, 'ID': 10007110})
# ('Samuel Clarridge', {'Historical Significance': 'Quaker activist', 'Gender': 'male', 'Birthdate': 1631, 'Deathdate': 1704, 'ID': 10002504})
# ('Thomas Lower', {'Historical Significance': 'Quaker activist and physician', 'Gender': 'male', 'Birthdate': 1633, 'Deathdate': 1720, 'ID': 10007626})
# ('Gervase Benson', {'Historical Significance': 'Quaker leader', 'Gender': 'male', 'Birthdate': 1569, 'Deathdate': 1679, 'ID': 10000972})
# ('Stephen Crisp', {'Historical Significance': 'Quaker activist and writer', 'Gender': 'male', 'Birthdate': 1628, 'Deathdate': 1692, 'ID': 10003022})
# ('James Claypoole', {'Historical Significance': 'merchant and pioneer settler in America', 'Gender': 'male', 'Birthdate': 1634, 'Deathdate': 1687, 'ID': 10002513})
# ('Thomas Holme', {'Historical Significance': 'Quaker missionary', 'Gender': 'male', 'Birthdate': 1626, 'Deathdate': 1666, 'ID': 10006100})
# ('John Freame', {'Historical Significance': 'banker and lobbyist', 'Gender': 'male', 'Birthdate': 1665, 'Deathdate': 1745, 'ID': 10004564})
# ('John Swinton', {'Historical Significance': 'politician', 'Gender': 'male', 'Birthdate': 1620, 'Deathdate': 1679, 'ID': 10011742})
# ('William Mead', {'Historical Significance': 'Quaker patron and merchant', 'Gender': 'male', 'Birthdate': 1627, 'Deathdate': 1713, 'ID': 10008161})
# ('Henry Pickworth', {'Historical Significance': 'religious controversialist', 'Gender': 'male', 'Birthdate': 1673, 'Deathdate': 1738, 'ID': 10009697})
# ('John Crook', {'Historical Significance': 'Quaker leader and writer', 'Gender': 'male', 'Birthdate': 1616, 'Deathdate': 1699, 'ID': 10003063})
# ('Gilbert Latey', {'Historical Significance': 'Quaker activist', 'Gender': 'male', 'Birthdate': 1626, 'Deathdate': 1705, 'ID': 10007166})
# ('Ellis Hookes', {'Historical Significance': 'Quaker administrator', 'Gender': 'male', 'Birthdate': 1635, 'Deathdate': 1681, 'ID': 10006146})
# ('Joseph Besse', {'Historical Significance': 'historian of Quakerism', 'Gender': 'male', 'Birthdate': 1683, 'Deathdate': 1757, 'ID': 10001027})
# ('James Nayler', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1618, 'Deathdate': 1660, 'ID': 10008713})
# ('Elizabeth Hooten', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1562, 'Deathdate': 1672, 'ID': 10006153})
# ('George Whitehead', {'Historical Significance': 'Quaker leader and writer', 'Gender': 'male', 'Birthdate': 1637, 'Deathdate': 1724, 'ID': 10012813})
# ('John Whitehead', {'Historical Significance': 'Quaker minister and preacher', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1696, 'ID': 10012815})
# ('William Crouch', {'Historical Significance': 'Quaker leader and writer', 'Gender': 'male', 'Birthdate': 1628, 'Deathdate': 1711, 'ID': 10003087})
# ('Benjamin Furly', {'Historical Significance': 'merchant and religious writer', 'Gender': 'male', 'Birthdate': 1636, 'Deathdate': 1714, 'ID': 10004625})
# ('Silvanus Bevan', {'Historical Significance': 'apothecary', 'Gender': 'male', 'Birthdate': 1691, 'Deathdate': 1765, 'ID': 10001041})
# ('Robert Rich', {'Historical Significance': 'Quaker adherent and sectary', 'Gender': 'male', 'Birthdate': 1607, 'Deathdate': 1679, 'ID': 10010260})
# ('John Whiting', {'Historical Significance': 'Quaker bibliographer and writer', 'Gender': 'male', 'Birthdate': 1656, 'Deathdate': 1722, 'ID': 10012829})
# ('Christopher Taylor', {'Historical Significance': 'religious writer and schoolmaster', 'Gender': 'male', 'Birthdate': 1614, 'Deathdate': 1686, 'ID': 10011811})
# ('Thomas Lawson', {'Historical Significance': 'Quaker minister and botanist', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1691, 'ID': 10007210})
# ('Richard Farnworth', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1630, 'Deathdate': 1666, 'ID': 10004141})
# ('William Coddington', {'Historical Significance': 'merchant and official in America', 'Gender': 'male', 'Birthdate': 1601, 'Deathdate': 1678, 'ID': 10002606})
# ('Thomas Taylor', {'Historical Significance': 'Quaker minister and writer', 'Gender': 'male', 'Birthdate': 1617, 'Deathdate': 1682, 'ID': 10011824})
# ('Richard Vickris', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1590, 'Deathdate': 1700, 'ID': 10012350})
# ('Robert Barclay', {'Historical Significance': 'religious writer and colonial governor', 'Gender': 'male', 'Birthdate': 1648, 'Deathdate': 1690, 'ID': 10054848})
# ('Jane Sowle', {'Historical Significance': nan, 'Gender': 'female', 'Birthdate': 1631, 'Deathdate': 1711, 'ID': 10011331})
# ('Tace Sowle', {'Historical Significance': 'printer and bookseller', 'Gender': 'male', 'Birthdate': 1666, 'Deathdate': 1749, 'ID': 10011332})
# ('Leonard Fell', {'Historical Significance': 'Quaker missionary and writer', 'Gender': 'male', 'Birthdate': 1624, 'Deathdate': 1701, 'ID': 10004169})
# ('Margaret Fell', {'Historical Significance': 'Quaker leader', 'Gender': 'female', 'Birthdate': 1614, 'Deathdate': 1702, 'ID': 10004170})
# ('George Bishop', {'Historical Significance': 'government official and religious writer', 'Gender': 'male', 'Birthdate': 1558, 'Deathdate': 1668, 'ID': 10001097})
# ('Elizabeth Leavens', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1555, 'Deathdate': 1665, 'ID': 10007246})
# ('Thomas Curtis', {'Historical Significance': 'Quaker schismatic', 'Gender': 'male', 'Birthdate': 1602, 'Deathdate': 1712, 'ID': 10003161})
# ('Alice Curwen', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1619, 'Deathdate': 1679, 'ID': 10003162})
# ('Alexander Parker', {'Historical Significance': 'Quaker preacher and author', 'Gender': 'male', 'Birthdate': 1628, 'Deathdate': 1689, 'ID': 10009307})
# ('John Wilkinson', {'Historical Significance': 'Quaker schismatic', 'Gender': 'male', 'Birthdate': 1652, 'Deathdate': 1683, 'ID': 10012893})
# ('Thomas Aldam', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1616, 'Deathdate': 1660, 'ID': 10000099})
# ('David Barclay of Ury', {'Historical Significance': 'soldier and politician', 'Gender': 'male', 'Birthdate': 1610, 'Deathdate': 1686, 'ID': 10000621})
# ('David Barclay', {'Historical Significance': 'merchant', 'Gender': 'male', 'Birthdate': 1682, 'Deathdate': 1769, 'ID': 10000622})
# ('Sir Charles Wager', {'Historical Significance': 'naval officer and politician', 'Gender': 'male', 'Birthdate': 1666, 'Deathdate': 1743, 'ID': 10012403})
# ('George Keith', {'Historical Significance': 'Quaker schismatic and Church of England clergyman', 'Gender': 'male', 'Birthdate': 1638, 'Deathdate': 1716, 'ID': 10006784})
# ('James Parnel', {'Historical Significance': 'Quaker martyr', 'Gender': 'male', 'Birthdate': 1636, 'Deathdate': 1656, 'ID': 10009347})
# ('Peter Collinson', {'Historical Significance': 'botanist', 'Gender': 'male', 'Birthdate': 1694, 'Deathdate': 1768, 'ID': 10002694})
# ('Franciscus Mercurius van Helmont', {'Historical Significance': 'physician and cabbalist', 'Gender': 'male', 'Birthdate': 1614, 'Deathdate': 1698, 'ID': 10005781})
# ('William Caton', {'Historical Significance': 'Quaker preacher', 'Gender': 'male', 'Birthdate': 1636, 'Deathdate': 1665, 'ID': 10002203})
# ('Francis Howgill', {'Historical Significance': 'Quaker activist', 'Gender': 'male', 'Birthdate': 1618, 'Deathdate': 1669, 'ID': 10006305})
# ('Richard Hubberthorne', {'Historical Significance': 'Quaker activist', 'Gender': 'male', 'Birthdate': 1628, 'Deathdate': 1662, 'ID': 10006314})
# ('William Ames', {'Historical Significance': 'Quaker preacher', 'Gender': 'male', 'Birthdate': 1552, 'Deathdate': 1662, 'ID': 10000175})
# ('William Rogers', {'Historical Significance': 'Quaker schismatic', 'Gender': 'male', 'Birthdate': 1601, 'Deathdate': 1711, 'ID': 10010417})
# ('Isaac Norris', {'Historical Significance': 'colonial official and merchant', 'Gender': 'male', 'Birthdate': 1671, 'Deathdate': 1735, 'ID': 10008884})
# ('Anthony Sharp', {'Historical Significance': 'Quaker leader', 'Gender': 'male', 'Birthdate': 1643, 'Deathdate': 1707, 'ID': 10010941})
# ('Mary Fisher', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1623, 'Deathdate': 1698, 'ID': 10004290})
# ('Anne Conway Viscountess Conway and Killultagh', {'Historical Significance': 'philosopher', 'Gender': 'female', 'Birthdate': 1631, 'Deathdate': 1679, 'ID': 10002755})
# ('Samuel Fisher', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'male', 'Birthdate': 1604, 'Deathdate': 1665, 'ID': 10004292})
# ('Francis Bugg', {'Historical Significance': 'Quaker apostate', 'Gender': 'male', 'Birthdate': 1640, 'Deathdate': 1727, 'ID': 10001737})
# ('Sarah Gibbons', {'Historical Significance': 'Quaker preacher in America', 'Gender': 'female', 'Birthdate': 1634, 'Deathdate': 1659, 'ID': 10004811})
# ('William Tomlinson', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1650, 'Deathdate': 1696, 'ID': 10011989})
# ('Humphrey Norton', {'Historical Significance': 'Quaker missionary and author', 'Gender': 'male', 'Birthdate': 1655, 'Deathdate': 1660, 'ID': 10008917})
# ('William Gibson', {'Historical Significance': 'Quaker leader', 'Gender': 'male', 'Birthdate': 1628, 'Deathdate': 1684, 'ID': 10004827})
# ('Gideon Wanton', {'Historical Significance': 'merchant and colonial governor', 'Gender': 'male', 'Birthdate': 1693, 'Deathdate': 1767, 'ID': 10012509})
# ('John Wanton', {'Historical Significance': 'merchant and colonial governor', 'Gender': 'male', 'Birthdate': 1672, 'Deathdate': 1740, 'ID': 10012510})
# ('Grace Chamber', {'Historical Significance': 'Quaker minister', 'Gender': 'female', 'Birthdate': 1676, 'Deathdate': 1762, 'ID': 10002274})
# ('Mary Prince', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1569, 'Deathdate': 1679, 'ID': 10009959})
# ('John Bartram', {'Historical Significance': 'botanist and explorer in America', 'Gender': 'male', 'Birthdate': 1699, 'Deathdate': 1777, 'ID': 10000745})
# ('Edward Haistwell', {'Historical Significance': 'merchant', 'Gender': 'male', 'Birthdate': 1658, 'Deathdate': 1709, 'ID': 10005359})
# ('John ap John', {'Historical Significance': 'Quaker leader', 'Gender': 'male', 'Birthdate': 1625, 'Deathdate': 1697, 'ID': 10000243})
# ('John Rous', {'Historical Significance': 'Quaker missionary', 'Gender': 'male', 'Birthdate': 1585, 'Deathdate': 1695, 'ID': 10010488})
# ('Anthony Pearson', {'Historical Significance': 'Quaker administrator', 'Gender': 'male', 'Birthdate': 1627, 'Deathdate': 1666, 'ID': 10009470})
# ('Solomon Eccles', {'Historical Significance': 'musician and Quaker missionary', 'Gender': 'male', 'Birthdate': 1617, 'Deathdate': 1682, 'ID': 10003859})
# ('John Burnyeat', {'Historical Significance': 'Quaker minister', 'Gender': 'male', 'Birthdate': 1631, 'Deathdate': 1690, 'ID': 10001815})
# ('Edward Burrough', {'Historical Significance': 'Quaker activist and writer', 'Gender': 'male', 'Birthdate': 1633, 'Deathdate': 1663, 'ID': 10001818})
# ('Rebecca Travers', {'Historical Significance': 'Quaker preacher and writer', 'Gender': 'female', 'Birthdate': 1609, 'Deathdate': 1688, 'ID': 10012062})
# ('William Edmundson', {'Historical Significance': 'Quaker leader', 'Gender': 'male', 'Birthdate': 1627, 'Deathdate': 1712, 'ID': 10003882})
# ('Sarah Cheevers', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1608, 'Deathdate': 1664, 'ID': 10002354})
# ('Edward Pyott', {'Historical Significance': 'parliamentarian army officer', 'Gender': 'male', 'Birthdate': 1560, 'Deathdate': 1670, 'ID': 10010036})
# ('Daniel Quare', {'Historical Significance': 'maker of clocks, watches, and barometers', 'Gender': 'male', 'Birthdate': 1648, 'Deathdate': 1724, 'ID': 10010037})
# ('John Penington', {'Historical Significance': 'Quaker apologist and controversialist', 'Gender': 'male', 'Birthdate': 1655, 'Deathdate': 1710, 'ID': 10009526})
# ('Mary Penington', {'Historical Significance': 'Quaker and writer', 'Gender': 'female', 'Birthdate': 1623, 'Deathdate': 1682, 'ID': 10009527})
# ('Charles Marshall', {'Historical Significance': 'Quaker preacher and apothecary', 'Gender': 'male', 'Birthdate': 1637, 'Deathdate': 1698, 'ID': 10007992})
# ('Humphrey Woolrich', {'Historical Significance': 'religious writer', 'Gender': 'male', 'Birthdate': 1633, 'Deathdate': 1707, 'ID': 10013112})
# ('William Penn', {'Historical Significance': 'Quaker leader and founder of Pennsylvania', 'Gender': 'male', 'Birthdate': 1644, 'Deathdate': 1718, 'ID': 10009531})
# ('Mary Pennyman', {'Historical Significance': nan, 'Gender': 'female', 'Birthdate': 1630, 'Deathdate': 1701, 'ID': 10009535})
# ('Dorothy Waugh', {'Historical Significance': 'Quaker preacher', 'Gender': 'female', 'Birthdate': 1636, 'Deathdate': 1666, 'ID': 10012614})
# ('David Lloyd', {'Historical Significance': 'lawyer and politician in America', 'Gender': 'male', 'Birthdate': 1656, 'Deathdate': 1731, 'ID': 10007509})
# ('Lewis Morris', {'Historical Significance': 'politician in America', 'Gender': 'male', 'Birthdate': 1671, 'Deathdate': 1746, 'ID': 10008534})
# ('Martha Simmonds', {'Historical Significance': 'Quaker and author', 'Gender': 'female', 'Birthdate': 1624, 'Deathdate': 1665, 'ID': 10011100})
# ('John Story', {'Historical Significance': 'Quaker schismatic', 'Gender': 'male', 'Birthdate': 1571, 'Deathdate': 1681, 'ID': 10011613})
# ('Thomas Story', {'Historical Significance': 'Quaker minister and journal writer', 'Gender': 'male', 'Birthdate': 1670, 'Deathdate': 1742, 'ID': 10011614})
# ('Thomas Ellwood', {'Historical Significance': 'religious controversialist', 'Gender': 'male', 'Birthdate': 1639, 'Deathdate': 1713, 'ID': 10003945})
# ('William Simpson', {'Historical Significance': 'Quaker preacher', 'Gender': 'male', 'Birthdate': 1627, 'Deathdate': 1671, 'ID': 10011114})
# ('Samuel Bownas', {'Historical Significance': 'Quaker minister and writer', 'Gender': 'male', 'Birthdate': 1677, 'Deathdate': 1753, 'ID': 10001390})
# ('John Perrot', {'Historical Significance': 'Quaker schismatic', 'Gender': 'male', 'Birthdate': 1555, 'Deathdate': 1665, 'ID': 10009584})
# ('Hannah Stranger', {'Historical Significance': 'Quaker missionary', 'Gender': 'female', 'Birthdate': 1656, 'Deathdate': 1671, 'ID': 10011632})

# %%
density = nx.density(G)
print("Network Density:", density)
# Out:
# Network Density: 0.02478279447372169

# %%
names = ("Margaret Fell", "George Whitehead")

ids = [x for x in G.nodes() if x in names]
print(ids)
# Out:
# ['George Whitehead', 'Margaret Fell']

# %%
path = nx.shortest_path(G, source=ids[0], target=ids[1])
print("Shortest path between {} & {}:".format(names[0], names[1]), path)
# Out:
# Shortest path between Margaret Fell & George Whitehead: ['George Whitehead', 'George Fox', 'Margaret Fell']

# %%
degrees = dict(G.degree())
nx.set_node_attributes(G, degrees, 'degree')
highestdegrees = sorted(degrees.items(), key=lambda x: x[1], reverse=True)[:10]

highestdegrees
# Out:
# [('George Fox', 22),
#  ('William Penn', 18),
#  ('James Nayler', 16),
#  ('George Whitehead', 13),
#  ('Margaret Fell', 13),
#  ('Benjamin Furly', 10),
#  ('Edward Burrough', 9),
#  ('George Keith', 8),
#  ('Thomas Ellwood', 8),
#  ('Francis Howgill', 7)]

# %%
between = nx.betweenness_centrality(G)

nx.set_node_attributes(G, between, 'between')

sorted_between = sorted(between.items(), key=lambda x: x[1], reverse=True)

print("Top 10 nodes by betweenness centrality:\n")

for d in sorted_between[:10]:
    print(" - {}: {:.5f}".format(d[0], d[1]))
# Out:
# Top 10 nodes by betweenness centrality:
#
#  - William Penn: 0.23999
#  - George Fox: 0.23683
#  - George Whitehead: 0.12632
#  - Margaret Fell: 0.12107
#  - James Nayler: 0.10446
#  - Benjamin Furly: 0.06420
#  - Thomas Ellwood: 0.04619
#  - George Keith: 0.04501
#  - John Audland: 0.04165
#  - Alexander Parker: 0.03894

# %%
nxa.draw_networkx(G, 
        node_size='degree:Q',
        node_color ='Gender:N',
        cmap = "set1",
        node_tooltip = 'name:N',
        linewidths = 0,
).properties(width=1000,height=1000)
# Out:
# alt.LayerChart(...)
